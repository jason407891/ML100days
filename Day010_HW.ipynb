# %%
from grab import Grab
g = Grab()
resp = g.go('https://google.com')
resp.body
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="zh-TW"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="psSbhLkj7RDESR+6yiam+g==">(function(){window.google={kEI:\'Bw-KYMDRI52Vr7wPhO2x6Aw\',kEXPI:\'0,1302536,56873,954,5104,207,4804,2316,383,246,5,1354,5251,1122515,1233,1196485,356,209,42,1,328941,51224,16114,17444,11240,9188,8384,4859,1361,9290,3021,4747,7,12834,4998,13228,1838,216,1793,4192,6430,14527,4518,2777,920,2276,8,2796,1593,1279,1042,1170,530,149,1103,840,517,1466,3,53,4258,108,3406,606,2023,1777,520,4269,328,1284,8789,3227,2845,9,4771,826,6755,5096,7539,337,4929,108,3407,908,2,941,2614,2397,7468,3277,3,576,1835,4625,148,5990,7985,4,498,1030,2304,1236,5227,2367,2893,2014,4067,9544,3011,1753,2658,4243,518,913,563,464,39,617,30,1324,6805,5499,1592,713,638,7080,10535,665,2145,3682,2302,228,2954,11
# ...

# %%
from pyquery import PyQuery as pq
doc = pq(resp.body)
title = doc('title')
print(title.text())
# Out:
# Google
