# %%
import requests
r=requests.get('https://www.dcard.tw/f')
print(r.text)
response=r.text
# Out:
# <!DOCTYPE html><html lang="zh-TW"><head prefix="og: http://ogp.me/ns#" itemscope="" itemType="https://schema.org/WebSite"><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="theme-color" content="#006aa6"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="supported-color-schemes" content="light"/><meta property="fb:app_id" content="211628828926493"/><meta property="fb:pages" content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764"/><link rel="preconnect" href="https://www.googletagmanager.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.googleapis.com" crossorigin="true"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link rel="dns-prefetch" href="https://www.googletagmanager.com"/><link rel="dns-prefetch" href="https://fonts.googleapis.com"/><link rel="dns-prefetch" href="https://fonts.gstatic.com"/><link rel="dns-prefetch" href="https://www.google-analytics.com"/><link rel="dns-prefetch" href="https://sb.scorecardresearch.com"/><link rel="dns-prefetch" href="https://certify.alexametrics.com"/><link rel="dns-prefetch" href="https://certify-js.alexametrics.com"/><link rel="dns-prefetch" href="https://megapx-assets.dcard.tw"/><link rel="dns-prefetch" href="https://browser.sentry-cdn.com"/><link rel="dns-prefetch" href="https://gcs.dcard.tw"/><link rel="dns-prefetch" href="https://bilanx.dcard.tw"/><link rel="dns-prefetch" href="https://imgur.dcard.tw"/><link rel="preload" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" as="style"/><link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap"/><meta charSet="utf-8"/><meta name="application-name" content="Dcard"/><meta property="al:ios:app_name" content="Dcard"/><meta property="al:android:app_name" content="Dcard"/><meta name="apple-itunes-app" content="app-id=951353454"/><meta property="al:ios:app_store_id" content="951353454"/><meta property="al:android:package" content="com.sparkslab.dcardreader"/><link rel="manifest" href="/_next/static/manifest-dcard.json"/><link rel="icon" type="image/png" sizes="48x48" href="/_next/static/media/dcard-icon-48-430d3ef4d3bdde2e349f5b7f9bcff0a3.png"/><link rel="icon" type="image/png" sizes="96x96" href="/_next/static/media/dcard-icon-96-733e6866a2105f9e0dd40258ad049315.png"/><link rel="icon" type="image/png" sizes="144x144" href="/_next/static/media/dcard-icon-144-e29b1dfa92ae6b6288184429b165f543.png"/><link rel="icon" type="image/png" sizes="192x192" href="/_next/static/media/dcard-icon-192-8ddcd08c7f194cf623c2e405e1689557.png"/><link rel="apple-touch-icon" type="image/png" sizes="57x57" href="/_next/static/media/dcard-icon-57-f33c45592fe2c81b9f6fa9f7689e0d17.png"/><link rel="apple-touch-icon" type="image/png" sizes="72x72" href="/_next/static/media/dcard-icon-72-4390490d91681428383d075d41977580.png"/><link rel="apple-touch-icon" type="image/png" sizes="76x76" href="/_next/static/media/dcard-icon-76-d6563e5ba905e13955938af1697d8015.png"/><link rel="apple-touch-icon" type="image/png" sizes="114x114" href="/_next/static/media/dcard-icon-114-b8fad6b9e2bc12d6516b58612539be50.png"/><link rel="apple-touch-icon" type="image/png" sizes="120x120" href="/_next/static/media/dcard-icon-120-f7c73abe77f9f8500bb2ab73cce5fa43.png"/><link rel="apple-touch-icon" type="image/png" sizes="144x144" href="/_next/static/media/dcard-icon-144-e29b1dfa92ae6b6288184429b165f543.png"/><link rel="apple-touch-icon" type="image/png" sizes="152x152" href="/_next/static/media/dcard-icon-152-298677be6ebcf68acf1efd932b138c47.png"/><link rel="apple-touch-icon" type="image/png" sizes="180x180" href="/_next/static/media/dcard-icon-180-53b4506f2ba6156616310137fa6f68a4.png"/><link rel="shortcut icon" type="image/png" href=" ...
# data-styled.g1[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .dvqhOE{fill:#e1e1e1;stroke:none;-webkit-transition:fill 0.15s cubic-bezier(0.4,0,0.2,1);transition:fill 0.15s cubic-bezier(0.4,0,0.2,1);object-fit:cover;display:inline-block;}/*!sc*/
# data-styled.g2[id="sc-husrwi"]{content:"dvqhOE,"}/*!sc*/
# .djtGLl{position:relative;display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g3[id="oo2grd-0"]{content:"djtGLl,"}/*!sc*/
# .dMOUny{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;}/*!sc*/
# data-styled.g5[id="oo2grd-2"]{content:"dMOUny,"}/*!sc*/
# .vyiBr{-webkit-appearance:none;-moz-appearance:none;appearance:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-weight:400;font-size:16px;line-height:22px;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);}/*!sc*/
# .vyiBr::-webkit-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .vyiBr::-moz-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .vyiBr:-ms-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .vyiBr::placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# data-styled.g7[id="oo2grd-4"]{content:"vyiBr,"}/*!sc*/
# .gVUpsb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .gVUpsb form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g10[id="dj0ioy-0"]{content:"gVUpsb,"}/*!sc*/
# .fysraG{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 8px;font-size:14px;color:#fff;}/*!sc*/
# .fysraG::-webkit-search-cancel-button{display:none;}/*!sc*/
# .fysraG::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g12[id="dj0ioy-2"]{content:"fysraG,"}/*!sc*/
# .kacUhU{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g13[id="dj0ioy-3"]{content:"kacUhU,"}/*!sc*/
# .dAVCLF{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g18[id="pkcmwm-0"]{content:"dAVCLF,"}/*!sc*/
# .dzaAJe{position:relative;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .dzaAJe:hover{color:rgba(0,0,0,1);}/*!sc*/
# .dzaAJe::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .jlRzxR{position:relative;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .jlRzxR:hover{color:rgba(0,0,0,1);}/*!sc*/
# .jlRzxR::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g19[id="pkcmwm-1"]{content:"dzaAJe,jlRzxR,"}/*!sc*/
# .idVSLh{--track-radius:3px;--track-size:8px;overflow:auto;width:100%;height:100%;}/*!sc*/
# data-styled.g33[id="sc-qz0f8b"]{content:"idVSLh,"}/*!sc*/
# .eRQARU{border-radius:var(--track-radius);background:transparent;-webkit-transition:background 200ms;transition:background 200ms;pointer-events:unset;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .simplebar-dragging .sc-bdvvaa,.eRQARU:hover{background:rgba(0,0,0,0.3);}/*!sc*/
# .eRQARU.simplebar-horizontal{height:var(--track-size);}/*!sc*/
# .eRQARU.simplebar-vertical{width:var(--track-size);}/*!sc*/
# data-styled.g34[id="sc-bdvvaa"]{content:"eRQARU,"}/*!sc*/
# .bhZOsZ{cursor:pointer;}/*!sc*/
# .bhZOsZ::before{border-radius:var(--track-radius);background:rgba(0,0,0,0.5);top:1px;bottom:1px;left:1px;right:1px;}/*!sc*/
# .simplebar-hover .sc-1dw6i8r::before,.simplebar-mouse-entered .bhZOsZ::before,.simplebar-dragging .bhZOsZ::before{top:0;bottom:0;left:0;right:0;}/*!sc*/
# .simplebar-scrolling .sc-1dw6i8r::before,.simplebar-hover .bhZOsZ::before,.simplebar-mouse-entered .bhZOsZ::before,.simplebar-dragging .bhZOsZ::before{opacity:1;}/*!sc*/
# .bhZOsZ.simplebar-visible::before{opacity:1;}/*!sc*/
# data-styled.g35[id="sc-1dw6i8r"]{content:"bhZOsZ,"}/*!sc*/
# .eOQgZp{border-radius:50%;overflow:hidden;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g76[id="yj50et-0"]{content:"eOQgZp,"}/*!sc*/
# .emcbOS{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# .empKoK{background:#006ea5;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g77[id="yj50et-1"]{content:"emcbOS,empKoK,"}/*!sc*/
# .epbkjc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g83[id="euk31c-0"]{content:"epbkjc,"}/*!sc*/
# .ftveEB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g84[id="euk31c-1"]{content:"ftveEB,"}/*!sc*/
# .hkziuG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g85[id="euk31c-2"]{content:"hkziuG,"}/*!sc*/
# .iVGtVg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.5);}/*!sc*/
# .iVGtVg:not(:last-child)::after{content:'・';}/*!sc*/
# data-styled.g86[id="euk31c-3"]{content:"iVGtVg,"}/*!sc*/
# .hBautw{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g87[id="euk31c-4"]{content:"hBautw,"}/*!sc*/
# .bpKuNv{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .jpJQOT{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g94[id="jjui6k-0"]{content:"bpKuNv,jpJQOT,"}/*!sc*/
# .BVTPe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# .BVTPe .sc-husrwi{width:24px;height:24px;fill:#fff;}/*!sc*/
# data-styled.g95[id="jjui6k-1"]{content:"BVTPe,"}/*!sc*/
# .bpkyqV{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g96[id="sc-1ahzbiw-0"]{content:"bpkyqV,"}/*!sc*/
# .dyeXwg{display:block;height:100%;}/*!sc*/
# data-styled.g97[id="sc-139xjgq-0"]{content:"dyeXwg,"}/*!sc*/
# .fgYDOw{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g98[id="dqjqtp-0"]{content:"fgYDOw,"}/*!sc*/
# .dZxiDA{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g106[id="fdq12b-0"]{content:"dZxiDA,"}/*!sc*/
# .dhKHYI .sc-1plrgiz-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g108[id="lhzs50-0"]{content:"dhKHYI,"}/*!sc*/
# .epaurX{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g109[id="dz5d85-0"]{content:"epaurX,"}/*!sc*/
# .ibYNxL{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g110[id="dz5d85-1"]{content:"ibYNxL,"}/*!sc*/
# .ijkWTi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g111[id="dz5d85-2"]{content:"ijkWTi,"}/*!sc*/
# .fZCpwm{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g116[id="bxef95-0"]{content:"fZCpwm,"}/*!sc*/
# .iGGWNS{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g117[id="bxef95-1"]{content:"iGGWNS,"}/*!sc*/
# .fvZEcc{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g140[id="gthja3-1"]{content:"fvZEcc,"}/*!sc*/
# .jGtkKv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .jGtkKv:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g147[id="sc-11gkikh-0"]{content:"jGtkKv,"}/*!sc*/
# .llxMbX{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# .llxMbX vmfive-ad-unit{width:100%;}/*!sc*/
# data-styled.g183[id="sc-1x2g0l4-0"]{content:"llxMbX,"}/*!sc*/
# .croAom{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g229[id="cgoejl-0"]{content:"croAom,"}/*!sc*/
# .liVVKX{display:block;border-radius:50%;border:2px solid #fff;margin-left:-4px;box-sizing:content-box;}/*!sc*/
# .liVVKX:first-child{margin-left:0;}/*!sc*/
# data-styled.g230[id="cgoejl-1"]{content:"liVVKX,"}/*!sc*/
# .fZnlej{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# .fZnlej .cgoejl-1{width:16px;height:16px;}/*!sc*/
# data-styled.g231[id="cgoejl-2"]{content:"fZnlej,"}/*!sc*/
# .jMiYgp{padding-left:6px;}/*!sc*/
# data-styled.g232[id="cgoejl-3"]{content:"jMiYgp,"}/*!sc*/
# .jTZxum{grid-area:thumb;overflow:hidden;border-radius:12px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g248[id="sc-2rneb0-0"]{content:"jTZxum,"}/*!sc*/
# .dfameG{height:1px;}/*!sc*/
# data-styled.g287[id="sc-1ocsimk-0"]{content:"dfameG,"}/*!sc*/
# .buWRCP{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g299[id="sc-1wisey8-0"]{content:"buWRCP,"}/*!sc*/
# .jhIZYh{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns 0.5s;transition:grid-template-columns 0.5s;}/*!sc*/
# data-styled.g473[id="bvk29r-0"]{content:"jhIZYh,"}/*!sc*/
# .cXYfzh{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g474[id="bvk29r-1"]{content:"cXYfzh,"}/*!sc*/
# .glwZhP{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g475[id="bvk29r-2"]{content:"glwZhP,"}/*!sc*/
# .PZtuP{grid-column:mainRight / end;}/*!sc*/
# data-styled.g476[id="bvk29r-3"]{content:"PZtuP,"}/*!sc*/
# .gsZYxo{margin:0 12px;min-height:calc( 100vh - 68px );min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g477[id="sc-10tqbnq-0"]{content:"gsZYxo,"}/*!sc*/
# .kuiJhT{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g478[id="sc-10tqbnq-1"]{content:"kuiJhT,"}/*!sc*/
# .cDiqBT{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g497[id="uj732l-0"]{content:"cDiqBT,"}/*!sc*/
# .fFUtFn{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g498[id="uj732l-1"]{content:"fFUtFn,"}/*!sc*/
# .eaMAYW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .eaMAYW:last-child{padding-right:0;}/*!sc*/
# .eaMAYW .sc-husrwi{width:20px;height:20px;margin-right:6px;}/*!sc*/
# .ghvDya{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .ghvDya:last-child{padding-right:0;}/*!sc*/
# .ghvDya .sc-husrwi{width:20px;height:20px;margin-right:6px;fill:#3397cf;}/*!sc*/
# data-styled.g499[id="uj732l-2"]{content:"eaMAYW,ghvDya,"}/*!sc*/
# .gFYeFH{position:relative;z-index:1;}/*!sc*/
# data-styled.g500[id="uj732l-4"]{content:"gFYeFH,"}/*!sc*/
# .bReysV{margin:0 60px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 0px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g501[id="tgn9uw-0"]{content:"bReysV,"}/*!sc*/
# .ceKcvN{font-size:14px;grid-area:header;}/*!sc*/
# data-styled.g502[id="tgn9uw-1"]{content:"ceKcvN,"}/*!sc*/
# .jWUdzO{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g503[id="tgn9uw-2"]{content:"jWUdzO,"}/*!sc*/
# .cUGTXH{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .cUGTXH::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g504[id="tgn9uw-3"]{content:"cUGTXH,"}/*!sc*/
# .jtaqbD{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g505[id="tgn9uw-4"]{content:"jtaqbD,"}/*!sc*/
# .cHyarR{font-size:14px;padding-left:4px;border-left:4px solid rgba(0,0,0,.15);color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g506[id="tgn9uw-5"]{content:"cHyarR,"}/*!sc*/
# .kvivaM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g524[id="j38qb8-0"]{content:"kvivaM,"}/*!sc*/
# .coCrfJ{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g525[id="j38qb8-1"]{content:"coCrfJ,"}/*!sc*/
# .ZDttY{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .ZDttY >:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g535[id="vnm9ni-0"]{content:"ZDttY,"}/*!sc*/
# .jdZdIW{position:relative;}/*!sc*/
# .jdZdIW::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g538[id="m2vgdk-0"]{content:"jdZdIW,"}/*!sc*/
# .hkUAph{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g571[id="sc-1bfxmuy-0"]{content:"hkUAph,"}/*!sc*/
# .iVjreC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:30px;height:30px;position:relative;}/*!sc*/
# .iVjreC .sc-husrwi{fill:#fff;width:24px;height:24px;}/*!sc*/
# data-styled.g572[id="sc-1bfxmuy-1"]{content:"iVjreC,"}/*!sc*/
# .bbqymi{border-radius:4px 4px 0 0;background-color:#fff;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g604[id="d4ydwz-0"]{content:"bbqymi,"}/*!sc*/
# .jLfDhx{background:#fff;}/*!sc*/
# data-styled.g606[id="sc-1db29sy-0"]{content:"jLfDhx,"}/*!sc*/
# .eAzWNg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g968[id="sc-1nqrhll-0"]{content:"eAzWNg,"}/*!sc*/
# .goKrVj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .goKrVj > *{height:100%;width:100%;}/*!sc*/
# data-styled.g969[id="sc-1nqrhll-1"]{content:"goKrVj,"}/*!sc*/
# .iQihnd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;}/*!sc*/
# data-styled.g971[id="sc-1iit2li-0"]{content:"iQihnd,"}/*!sc*/
# .hOwDyB{position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;border-bottom:1px solid rgba(0,0,0,0.15);border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g972[id="sc-1iit2li-1"]{content:"hOwDyB,"}/*!sc*/
# .jOgXbG{width:100%;z-index:1;}/*!sc*/
# data-styled.g978[id="sc-1iit2li-7"]{content:"jOgXbG,"}/*!sc*/
# .cpFflv{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g979[id="sc-1kb03aj-0"]{content:"cpFflv,"}/*!sc*/
# </style></head><body><div id="__next"><div class="bxef95-0 fZCpwm"><div class="dz5d85-0 epaurX"><div class="dz5d85-1 ibYNxL"><a title="Dcard" class="dqjqtp-0 fgYDOw" href="/f"><img class="sc-139xjgq-0 dyeXwg" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg" alt="Dcard"/></a><div class="bxef95-1 iGGWNS"><div class="dj0ioy-0 gVUpsb"><form action=""><label class="oo2grd-0 djtGLl"><div class="oo2grd-2 dMOUny"><input type="search" placeholder="搜尋" aria-label="搜尋" class="oo2grd-4 vyiBr dj0ioy-2 fysraG" value=""/></div></label><button type="submit" title="搜尋" disabled="" class="dj0ioy-3 kacUhU"><svg viewBox="0 0 28 28" class="sc-husrwi dvqhOE dj0ioy-7 dbNcOQ" focusable="false" width="20" height="20" style="fill:#fff" role="img" aria-hidden="true"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></button></form></div></div></div><div role="navigation" class="dz5d85-2 ijkWTi"><a class="jjui6k-0 bpKuNv sc-1ahzbiw-0 bpkyqV" role="button" href="/signup"><span class="jjui6k-1 BVTPe">註冊 / 登入</span></a><div class="fdq12b-0 dZxiDA"><a class="jjui6k-0 jpJQOT" title="更多" role="button"><span class="jjui6k-1 BVTPe"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="sc-husrwi dvqhOE"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path fill="none" d="M0 0h24v24H0z"></path></svg></span></a></div></div></div></div><div class="bvk29r-0 jhIZYh"><div class="bvk29r-1 cXYfzh"><div class="sc-1bfxmuy-0 hkUAph"><a href="/forum/all"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="sc-husrwi dvqhOE"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></div><div class="gthja3-1 fvZEcc">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg viewBox="0 0 24 24" focusable="false" role="img" aria-hidden="true" class="sc-husrwi dvqhOE"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></div><div class="gthja3-1 fvZEcc">即時熱門看板</div></div></a><a href="/goods"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 24 24" class="sc-husrwi dvqhOE m2vgdk-0 jdZdIW" focusable="false" width="24" height="24" style="fill:#fff" role="img" aria-hidden="true"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"></path><path fill="none" d="M0 0h24v24H0z"></path></svg></div><div class="gthja3-1 fvZEcc">好物研究室</div></div></a><div class="sc-qz0f8b idVSLh"><div class="simp ...
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();</script><noscript><img src="https://certify.alexametrics.com/atrk.gif?account=gj89j1a8Dy000J" style="display:none" height="1" width="1" alt=""/></noscript></div><noscript><img src="https://sb.scorecardresearch.com/p?c1=2&c2=33827916&cv=2.0&cj=1"/></noscript><script id="__INTL_REGISTRY__" type="application/json">{"meta.dcard_app.description_format":"廣受年輕人喜愛的 {product} 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！","search.main.action":"搜尋","form_validation.is_required.message":"此欄位為必填。","signup.login_or_signup.action":"註冊 / 登入","settings.end_user_agreement.option":"服務條款","settings.faq.option":"常見問題","general.report_problem.description":"回報問題","general.brand_identification.description":"品牌識別","general.hiring.description":"徵才","general.business.description":"商業合作","general.free_to_download.description":"免費下載 App","settings.main.title":"設定","member.logout.action":"登出","general.more.action":"更多","forum_list.all_title.option":"所有看板","forum_list.realtime_popular.title":"即時熱門看板","ec.short.title":"好物研究室","forum_list.moderator.title":"板主相關","forum_list.favorites.title":"我的最愛","forum_list.selected.title_format":"{product} 精選看板","forum.all.title":"全部","collection.put.action":"收藏","post.anonymous.description":"匿名","time_format.less_than_seven_day.description_format":"{days} 天前","member.gender_male.option":"男","member.gender_female.option":"女","time_format.less_than_one_day.description_format":"{hours} 小時前","forum.welcome.message_format":"歡迎來到{forumName}板。"}</script><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"layoutInitialProps":{"layoutInitialProps":{"layoutInitialProps":{},"componentInitialProps":{}},"componentInitialProps":{}},"componentInitialProps":{"envelope":{"pager":"legacy","options":{"paginationOptions":{"forumAlias":"all"},"isPessoalButNotLoggedin":false,"sourceKey":"hot"}},"forumAlias":"all","tabQuery":{},"tabs":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy","nameMessage":{"type":"string","message":"熱門"},"isHome":false},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy","nameMessage":{"type":"string","message":"最新"},"isHome":false},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy","nameMessage":{"type":"string","message":"追蹤"},"isHome":false}],"query":{},"kbkPosts":[]}},"isLogin":false,"isMobile":false,"initialState":{"adItem":{"data":{"558bae61-cb3c-4604-b281-473b6bf1047d":[],"f0fc1371-7da6-472b-be89-6392f8869ea4":[],"2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[],"a0d23a73-66bb-4704-af18-286c6b0292f9":[],"63463c6f-e951-4d18-b559-6e6c5e629ec3":[],"e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[],"d1555d99-c344-499a-b0ee-fadfa2f2b216":[],"adUnitId=558bae61-cb3c-4604-b281-473b6bf1047d":[{"provider":"google","id":"/146730420/Desktop-Right-Top"}],"adUnitId=f0fc1371-7da6-472b-be89-6392f8869ea4":[{"provider":"google","id":"/146730420/Desktop-Beyond-FB"}],"adUnitId=2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[{"provider":"google","id":"/146730420/Desktop-Right3"}],"adUnitId=a0d23a73-66bb-4704-af18-286c6b0292f9":[{"provider":"google","id":"/146730420/Desktop-Right4"}],"adUnitId=63463c6f-e951-4d18-b559-6e6c5e629ec3":[{"provider":"google","id":"/146730420/Desktop-RightBottom-Bottom"}],"adUnitId=e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[{"provider":"google","id":"/146730420/Desktop-Article-Bottom"}],"adUnitId=d1555d99-c344-499a-b0ee-fadfa2f2b216":[{"provider":"google","id":"/146730420/Desktop-Comments"}],"adUnitId=e4d31040-b6b8-4479-9585-a28bd1c16832":[{"provider":"google","id":"/146730420/Mobile-Web-Screen-Top"}],"adUnitId=0c24cee5-97e0-486b-9dc1-b7d36bea93cb":[{"provider":"google","id":"/146730420/Mobile-Web-Article-End"}],"adUnitId=49317a19-f96f-42df-9dee-76bf1d62b6f9":[{"provider":"google","id":"/146730420/Mweb-Popular-Comment ...

# %%
print(type(r))
print(type(response))
# Out:
# <class 'requests.models.Response'>
# <class 'str'>

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(r.text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="zh-TW"><head itemscope="" itemtype="https://schema.org/WebSite" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><meta content="#006aa6" name="theme-color"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="light" name="supported-color-schemes"/><meta content="211628828926493" property="fb:app_id"/><meta content="178875832200695,577748865730563,1333515469994506,619122564952487,804004803032067,178024805867764" property="fb:pages"/><link crossorigin="true" href="https://www.googletagmanager.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.googleapis.com" rel="preconnect"/><link crossorigin="true" href="https://fonts.gstatic.com" rel="preconnect"/><link href="https://www.googletagmanager.com" rel="dns-prefetch"/><link href="https://fonts.googleapis.com" rel="dns-prefetch"/><link href="https://fonts.gstatic.com" rel="dns-prefetch"/><link href="https://www.google-analytics.com" rel="dns-prefetch"/><link href="https://sb.scorecardresearch.com" rel="dns-prefetch"/><link href="https://certify.alexametrics.com" rel="dns-prefetch"/><link href="https://certify-js.alexametrics.com" rel="dns-prefetch"/><link href="https://megapx-assets.dcard.tw" rel="dns-prefetch"/><link href="https://browser.sentry-cdn.com" rel="dns-prefetch"/><link href="https://gcs.dcard.tw" rel="dns-prefetch"/><link href="https://bilanx.dcard.tw" rel="dns-prefetch"/><link href="https://imgur.dcard.tw" rel="dns-prefetch"/><link as="style" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="preload"/><link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;500;700&amp;display=swap" rel="stylesheet"/><meta charset="utf-8"/><meta content="Dcard" name="application-name"/><meta content="Dcard" property="al:ios:app_name"/><meta content="Dcard" property="al:android:app_name"/><meta content="app-id=951353454" name="apple-itunes-app"/><meta content="951353454" property="al:ios:app_store_id"/><meta content="com.sparkslab.dcardreader" property="al:android:package"/><link href="/_next/static/manifest-dcard.json" rel="manifest"/><link href="/_next/static/media/dcard-icon-48-430d3ef4d3bdde2e349f5b7f9bcff0a3.png" rel="icon" sizes="48x48" type="image/png"/><link href="/_next/static/media/dcard-icon-96-733e6866a2105f9e0dd40258ad049315.png" rel="icon" sizes="96x96" type="image/png"/><link href="/_next/static/media/dcard-icon-144-e29b1dfa92ae6b6288184429b165f543.png" rel="icon" sizes="144x144" type="image/png"/><link href="/_next/static/media/dcard-icon-192-8ddcd08c7f194cf623c2e405e1689557.png" rel="icon" sizes="192x192" type="image/png"/><link href="/_next/static/media/dcard-icon-57-f33c45592fe2c81b9f6fa9f7689e0d17.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/><link href="/_next/static/media/dcard-icon-72-4390490d91681428383d075d41977580.png" rel="apple-touch-icon" sizes="72x72" type="image/png"/><link href="/_next/static/media/dcard-icon-76-d6563e5ba905e13955938af1697d8015.png" rel="apple-touch-icon" sizes="76x76" type="image/png"/><link href="/_next/static/media/dcard-icon-114-b8fad6b9e2bc12d6516b58612539be50.png" rel="apple-touch-icon" sizes="114x114" type="image/png"/><link href="/_next/static/media/dcard-icon-120-f7c73abe77f9f8500bb2ab73cce5fa43.png" rel="apple-touch-icon" sizes="120x120" type="image/png"/><link href="/_next/static/media/dcard-icon-144-e29b1dfa92ae6b6288184429b165f543.png" rel="apple-touch-icon" sizes="144x144" type="image/png"/><link href="/_next/static/media/dcard-icon-152-298677be6ebcf68acf1efd932b138c47.png" rel="apple-touch-icon" sizes="152x152" type="image/png"/><link href="/_next/static/media/dcard-icon-180-53b4506f2ba6156616310137fa6f68a4.png" rel="apple-touch-icon" sizes="180x180" type="image/png"/><link href="/_next/static/media/dcard-icon-48-430d3ef4d3bdde2e34 ...
# data-styled.g1[id="sc-global-MmJWH1"]{content:"sc-global-MmJWH1,"}/*!sc*/
# .dvqhOE{fill:#e1e1e1;stroke:none;-webkit-transition:fill 0.15s cubic-bezier(0.4,0,0.2,1);transition:fill 0.15s cubic-bezier(0.4,0,0.2,1);object-fit:cover;display:inline-block;}/*!sc*/
# data-styled.g2[id="sc-husrwi"]{content:"dvqhOE,"}/*!sc*/
# .djtGLl{position:relative;display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g3[id="oo2grd-0"]{content:"djtGLl,"}/*!sc*/
# .dMOUny{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;min-width:130px;max-width:640px;height:100%;}/*!sc*/
# data-styled.g5[id="oo2grd-2"]{content:"dMOUny,"}/*!sc*/
# .vyiBr{-webkit-appearance:none;-moz-appearance:none;appearance:none;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 13px;outline:none;border:1px solid rgba(0,0,0,0.15);font-weight:400;font-size:16px;line-height:22px;cursor:text;-webkit-flex:1;-ms-flex:1;flex:1;border-radius:10px;color:rgba(0,0,0,.85);}/*!sc*/
# .vyiBr::-webkit-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .vyiBr::-moz-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .vyiBr:-ms-input-placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# .vyiBr::placeholder{color:rgba(0,0,0,0.35);}/*!sc*/
# data-styled.g7[id="oo2grd-4"]{content:"vyiBr,"}/*!sc*/
# .gVUpsb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;}/*!sc*/
# .gVUpsb form{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;background:#00588a;border-radius:4px;overflow:hidden;width:100%;}/*!sc*/
# data-styled.g10[id="dj0ioy-0"]{content:"gVUpsb,"}/*!sc*/
# .fysraG{-webkit-flex:1;-ms-flex:1;flex:1;border:none;background:none;height:100%;padding:0 8px;font-size:14px;color:#fff;}/*!sc*/
# .fysraG::-webkit-search-cancel-button{display:none;}/*!sc*/
# .fysraG::-webkit-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG::-moz-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG:-ms-input-placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# .fysraG::placeholder{color:rgba(255,255,255,0.75);}/*!sc*/
# data-styled.g12[id="dj0ioy-2"]{content:"fysraG,"}/*!sc*/
# .kacUhU{background:#006aa6;border:1px solid #00588a;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:0 4px 4px 0;padding:0 9px;cursor:pointer;outline:none;}/*!sc*/
# data-styled.g13[id="dj0ioy-3"]{content:"kacUhU,"}/*!sc*/
# .dAVCLF{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# data-styled.g18[id="pkcmwm-0"]{content:"dAVCLF,"}/*!sc*/
# .dzaAJe{position:relative;color:rgba(0,0,0,1);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .dzaAJe:hover{color:rgba(0,0,0,1);}/*!sc*/
# .dzaAJe::after{content:'';border-bottom:2px solid #3397cf;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# .jlRzxR{position:relative;color:rgba(0,0,0,0.35);cursor:pointer;padding:0 16px;font-weight:500;font-size:16px;line-height:22px;height:60px;line-height:60px;font-size:16px;}/*!sc*/
# .jlRzxR:hover{color:rgba(0,0,0,1);}/*!sc*/
# .jlRzxR::after{content:'';border-bottom:2px solid transparent;position:absolute;left:0;bottom:-1px;width:100%;}/*!sc*/
# data-styled.g19[id="pkcmwm-1"]{content:"dzaAJe,jlRzxR,"}/*!sc*/
# .idVSLh{--track-radius:3px;--track-size:8px;overflow:auto;width:100%;height:100%;}/*!sc*/
# data-styled.g33[id="sc-qz0f8b"]{content:"idVSLh,"}/*!sc*/
# .eRQARU{border-radius:var(--track-radius);background:transparent;-webkit-transition:background 200ms;transition:background 200ms;pointer-events:unset;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# .simplebar-dragging .sc-bdvvaa,.eRQARU:hover{background:rgba(0,0,0,0.3);}/*!sc*/
# .eRQARU.simplebar-horizontal{height:var(--track-size);}/*!sc*/
# .eRQARU.simplebar-vertical{width:var(--track-size);}/*!sc*/
# data-styled.g34[id="sc-bdvvaa"]{content:"eRQARU,"}/*!sc*/
# .bhZOsZ{cursor:pointer;}/*!sc*/
# .bhZOsZ::before{border-radius:var(--track-radius);background:rgba(0,0,0,0.5);top:1px;bottom:1px;left:1px;right:1px;}/*!sc*/
# .simplebar-hover .sc-1dw6i8r::before,.simplebar-mouse-entered .bhZOsZ::before,.simplebar-dragging .bhZOsZ::before{top:0;bottom:0;left:0;right:0;}/*!sc*/
# .simplebar-scrolling .sc-1dw6i8r::before,.simplebar-hover .bhZOsZ::before,.simplebar-mouse-entered .bhZOsZ::before,.simplebar-dragging .bhZOsZ::before{opacity:1;}/*!sc*/
# .bhZOsZ.simplebar-visible::before{opacity:1;}/*!sc*/
# data-styled.g35[id="sc-1dw6i8r"]{content:"bhZOsZ,"}/*!sc*/
# .eOQgZp{border-radius:50%;overflow:hidden;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g76[id="yj50et-0"]{content:"eOQgZp,"}/*!sc*/
# .emcbOS{background:#cb3a6b;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# .empKoK{background:#006ea5;color:#fff;font-size:10.24px;height:16px;width:16px;line-height:16px;text-align:center;border-radius:50%;}/*!sc*/
# data-styled.g77[id="yj50et-1"]{content:"emcbOS,empKoK,"}/*!sc*/
# .epbkjc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:14px;}/*!sc*/
# data-styled.g83[id="euk31c-0"]{content:"epbkjc,"}/*!sc*/
# .ftveEB{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;margin-right:10px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g84[id="euk31c-1"]{content:"ftveEB,"}/*!sc*/
# .hkziuG{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g85[id="euk31c-2"]{content:"hkziuG,"}/*!sc*/
# .iVGtVg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.5);}/*!sc*/
# .iVGtVg:not(:last-child)::after{content:'・';}/*!sc*/
# data-styled.g86[id="euk31c-3"]{content:"iVGtVg,"}/*!sc*/
# .hBautw{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:8px;}/*!sc*/
# data-styled.g87[id="euk31c-4"]{content:"hBautw,"}/*!sc*/
# .bpKuNv{width:60px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# .jpJQOT{width:px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:0 2px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;color:rgba(255,255,255,0.6);height:100%;pointer-events:all;opacity:1;}/*!sc*/
# data-styled.g94[id="jjui6k-0"]{content:"bpKuNv,jpJQOT,"}/*!sc*/
# .BVTPe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;line-height:1;color:#fff;}/*!sc*/
# .BVTPe .sc-husrwi{width:24px;height:24px;fill:#fff;}/*!sc*/
# data-styled.g95[id="jjui6k-1"]{content:"BVTPe,"}/*!sc*/
# .bpkyqV{width:auto;padding:0 16px;}/*!sc*/
# data-styled.g96[id="sc-1ahzbiw-0"]{content:"bpkyqV,"}/*!sc*/
# .dyeXwg{display:block;height:100%;}/*!sc*/
# data-styled.g97[id="sc-139xjgq-0"]{content:"dyeXwg,"}/*!sc*/
# .fgYDOw{height:100%;padding:10px 0;display:block;}/*!sc*/
# data-styled.g98[id="dqjqtp-0"]{content:"fgYDOw,"}/*!sc*/
# .dZxiDA{height:100%;width:-webkit-fit-content;width:-moz-fit-content;width:fit-content;}/*!sc*/
# data-styled.g106[id="fdq12b-0"]{content:"dZxiDA,"}/*!sc*/
# .dhKHYI .sc-1plrgiz-0{max-height:calc(100vh - 48px - 5px);overflow:auto;}/*!sc*/
# data-styled.g108[id="lhzs50-0"]{content:"dhKHYI,"}/*!sc*/
# .epaurX{max-width:1280px;height:100%;margin:auto;padding:0 20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g109[id="dz5d85-0"]{content:"epaurX,"}/*!sc*/
# .ibYNxL{height:100%;-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 16px;}/*!sc*/
# data-styled.g110[id="dz5d85-1"]{content:"ibYNxL,"}/*!sc*/
# .ijkWTi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g111[id="dz5d85-2"]{content:"ijkWTi,"}/*!sc*/
# .fZCpwm{position:fixed;top:0;z-index:11;height:48px;width:100%;background:#006aa6;}/*!sc*/
# data-styled.g116[id="bxef95-0"]{content:"fZCpwm,"}/*!sc*/
# .iGGWNS{padding:0 32px;max-width:666px;min-width:200px;height:30px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g117[id="bxef95-1"]{content:"iGGWNS,"}/*!sc*/
# .fvZEcc{font-size:16px;margin:0 10px 0 8px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g140[id="gthja3-1"]{content:"fvZEcc,"}/*!sc*/
# .jGtkKv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:44px;padding:0 10px 0 20px;color:rgba(255,255,255,0.75);cursor:pointer;}/*!sc*/
# .jGtkKv:hover{background-color:rgba(0,0,0,0.2);}/*!sc*/
# data-styled.g147[id="sc-11gkikh-0"]{content:"jGtkKv,"}/*!sc*/
# .llxMbX{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# .llxMbX vmfive-ad-unit{width:100%;}/*!sc*/
# data-styled.g183[id="sc-1x2g0l4-0"]{content:"llxMbX,"}/*!sc*/
# .croAom{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g229[id="cgoejl-0"]{content:"croAom,"}/*!sc*/
# .liVVKX{display:block;border-radius:50%;border:2px solid #fff;margin-left:-4px;box-sizing:content-box;}/*!sc*/
# .liVVKX:first-child{margin-left:0;}/*!sc*/
# data-styled.g230[id="cgoejl-1"]{content:"liVVKX,"}/*!sc*/
# .fZnlej{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;opacity:0.75;}/*!sc*/
# .fZnlej .cgoejl-1{width:16px;height:16px;}/*!sc*/
# data-styled.g231[id="cgoejl-2"]{content:"fZnlej,"}/*!sc*/
# .jMiYgp{padding-left:6px;}/*!sc*/
# data-styled.g232[id="cgoejl-3"]{content:"jMiYgp,"}/*!sc*/
# .jTZxum{grid-area:thumb;overflow:hidden;border-radius:12px;border:1px solid rgba(0,0,0,0.1);object-fit:cover;margin-left:20px;}/*!sc*/
# data-styled.g248[id="sc-2rneb0-0"]{content:"jTZxum,"}/*!sc*/
# .dfameG{height:1px;}/*!sc*/
# data-styled.g287[id="sc-1ocsimk-0"]{content:"dfameG,"}/*!sc*/
# .buWRCP{-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g299[id="sc-1wisey8-0"]{content:"buWRCP,"}/*!sc*/
# .jhIZYh{display:grid;max-width:1280px;margin:auto;padding:48px 20px 0 0;grid-template-columns:[start] 208px [mainLeft] auto [mainRight] 300px [end];-webkit-transition:grid-template-columns 0.5s;transition:grid-template-columns 0.5s;}/*!sc*/
# data-styled.g473[id="bvk29r-0"]{content:"jhIZYh,"}/*!sc*/
# .cXYfzh{grid-column:start / mainLeft;}/*!sc*/
# data-styled.g474[id="bvk29r-1"]{content:"cXYfzh,"}/*!sc*/
# .glwZhP{min-width:calc(728px + 24px);grid-column:mainLeft / mainRight;}/*!sc*/
# data-styled.g475[id="bvk29r-2"]{content:"glwZhP,"}/*!sc*/
# .PZtuP{grid-column:mainRight / end;}/*!sc*/
# data-styled.g476[id="bvk29r-3"]{content:"PZtuP,"}/*!sc*/
# .gsZYxo{margin:0 12px;min-height:calc( 100vh - 68px );min-width:728px;padding-top:20px;height:100%;}/*!sc*/
# data-styled.g477[id="sc-10tqbnq-0"]{content:"gsZYxo,"}/*!sc*/
# .kuiJhT{height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g478[id="sc-10tqbnq-1"]{content:"kuiJhT,"}/*!sc*/
# .cDiqBT{grid-area:main;overflow:hidden;}/*!sc*/
# data-styled.g497[id="uj732l-0"]{content:"cDiqBT,"}/*!sc*/
# .fFUtFn{color:rgba(0,0,0,.35);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;grid-area:footer;overflow:hidden;}/*!sc*/
# data-styled.g498[id="uj732l-1"]{content:"fFUtFn,"}/*!sc*/
# .eaMAYW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .eaMAYW:last-child{padding-right:0;}/*!sc*/
# .eaMAYW .sc-husrwi{width:20px;height:20px;margin-right:6px;}/*!sc*/
# .ghvDya{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-right:16px;}/*!sc*/
# .ghvDya:last-child{padding-right:0;}/*!sc*/
# .ghvDya .sc-husrwi{width:20px;height:20px;margin-right:6px;fill:#3397cf;}/*!sc*/
# data-styled.g499[id="uj732l-2"]{content:"eaMAYW,ghvDya,"}/*!sc*/
# .gFYeFH{position:relative;z-index:1;}/*!sc*/
# data-styled.g500[id="uj732l-4"]{content:"gFYeFH,"}/*!sc*/
# .bReysV{margin:0 60px;border-bottom:1px solid rgb(233,233,233);position:relative;padding:20px 0px;display:grid;grid-template-areas:'header header' '. .' 'title thumb' '. thumb' 'main thumb' '. thumb' 'footer thumb';grid-template-columns:1fr auto;grid-template-rows:auto 12px auto 4px auto 16px auto;cursor:pointer;-webkit-tap-highlight-color:transparent;}/*!sc*/
# data-styled.g501[id="tgn9uw-0"]{content:"bReysV,"}/*!sc*/
# .ceKcvN{font-size:14px;grid-area:header;}/*!sc*/
# data-styled.g502[id="tgn9uw-1"]{content:"ceKcvN,"}/*!sc*/
# .jWUdzO{grid-area:title;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g503[id="tgn9uw-2"]{content:"jWUdzO,"}/*!sc*/
# .cUGTXH{font-weight:600;font-size:18px;line-height:25px;color:rgba(0,0,0,1);}/*!sc*/
# .cUGTXH::after{content:'';position:absolute;z-index:0;top:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g504[id="tgn9uw-3"]{content:"cUGTXH,"}/*!sc*/
# .jtaqbD{font-weight:400;font-size:14px;line-height:20px;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;color:rgba(0,0,0,0.75);}/*!sc*/
# data-styled.g505[id="tgn9uw-4"]{content:"jtaqbD,"}/*!sc*/
# .cHyarR{font-size:14px;padding-left:4px;border-left:4px solid rgba(0,0,0,.15);color:rgba(0,0,0,.6);white-space:nowrap;text-overflow:ellipsis;overflow:hidden;}/*!sc*/
# data-styled.g506[id="tgn9uw-5"]{content:"cHyarR,"}/*!sc*/
# .kvivaM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;color:rgba(255,255,255,0.6);margin:-3px -5px;}/*!sc*/
# data-styled.g524[id="j38qb8-0"]{content:"kvivaM,"}/*!sc*/
# .coCrfJ{color:rgba(255,255,255,0.6);margin:3px 5px;}/*!sc*/
# data-styled.g525[id="j38qb8-1"]{content:"coCrfJ,"}/*!sc*/
# .ZDttY{position:-webkit-sticky;position:sticky;top:calc( 100vh - 100vh + 58px );margin:20px 0;min-width:300px;min-height:calc(100vh - 88px);width:300px;}/*!sc*/
# .ZDttY >:not(:last-child){margin-bottom:10px;}/*!sc*/
# data-styled.g535[id="vnm9ni-0"]{content:"ZDttY,"}/*!sc*/
# .jdZdIW{position:relative;}/*!sc*/
# .jdZdIW::after{top:0;right:0;-webkit-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);-ms-transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);transform:translate3d(calc(50% - 1px),calc(-50% + 1px),0);position:absolute;content:'';border-radius:50%;width:10px;height:10px;border:1px solid #fff;background-color:#ea5c5c;display:none;}/*!sc*/
# data-styled.g538[id="m2vgdk-0"]{content:"jdZdIW,"}/*!sc*/
# .hkUAph{position:-webkit-sticky;position:sticky;top:68px;height:calc(100vh - 88px);min-width:208px;width:208px;margin:20px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}/*!sc*/
# data-styled.g571[id="sc-1bfxmuy-0"]{content:"hkUAph,"}/*!sc*/
# .iVjreC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;width:30px;height:30px;position:relative;}/*!sc*/
# .iVjreC .sc-husrwi{fill:#fff;width:24px;height:24px;}/*!sc*/
# data-styled.g572[id="sc-1bfxmuy-1"]{content:"iVjreC,"}/*!sc*/
# .bbqymi{border-radius:4px 4px 0 0;background-color:#fff;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g604[id="d4ydwz-0"]{content:"bbqymi,"}/*!sc*/
# .jLfDhx{background:#fff;}/*!sc*/
# data-styled.g606[id="sc-1db29sy-0"]{content:"jLfDhx,"}/*!sc*/
# .eAzWNg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:60px;}/*!sc*/
# data-styled.g968[id="sc-1nqrhll-0"]{content:"eAzWNg,"}/*!sc*/
# .goKrVj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;}/*!sc*/
# .goKrVj > *{height:100%;width:100%;}/*!sc*/
# data-styled.g969[id="sc-1nqrhll-1"]{content:"goKrVj,"}/*!sc*/
# .iQihnd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;background:#fff;}/*!sc*/
# data-styled.g971[id="sc-1iit2li-0"]{content:"iQihnd,"}/*!sc*/
# .hOwDyB{position:-webkit-sticky;position:sticky;top:48px;padding:20px 60px 0;z-index:10;border-bottom:1px solid rgba(0,0,0,0.15);border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g972[id="sc-1iit2li-1"]{content:"hOwDyB,"}/*!sc*/
# .jOgXbG{width:100%;z-index:1;}/*!sc*/
# data-styled.g978[id="sc-1iit2li-7"]{content:"jOgXbG,"}/*!sc*/
# .cpFflv{border-radius:4px 4px 0 0;}/*!sc*/
# data-styled.g979[id="sc-1kb03aj-0"]{content:"cpFflv,"}/*!sc*/
# </style></head><body><div id="__next"><div class="bxef95-0 fZCpwm"><div class="dz5d85-0 epaurX"><div class="dz5d85-1 ibYNxL"><a class="dqjqtp-0 fgYDOw" href="/f" title="Dcard"><img alt="Dcard" class="sc-139xjgq-0 dyeXwg" src="/_next/static/media/logo-2ef7b50901acaa284f36a0484329ec05.svg"/></a><div class="bxef95-1 iGGWNS"><div class="dj0ioy-0 gVUpsb"><form action=""><label class="oo2grd-0 djtGLl"><div class="oo2grd-2 dMOUny"><input aria-label="搜尋" class="oo2grd-4 vyiBr dj0ioy-2 fysraG" placeholder="搜尋" type="search" value=""/></div></label><button class="dj0ioy-3 kacUhU" disabled="" title="搜尋" type="submit"><svg aria-hidden="true" class="sc-husrwi dvqhOE dj0ioy-7 dbNcOQ" focusable="false" height="20" role="img" style="fill:#fff" viewbox="0 0 28 28" width="20"><path d="M22.9 21.2l-4.5-4.5A7.5 7.5 0 1017 18l4.5 4.5a.5.5 0 00.8 0l.5-.5a.5.5 0 000-.8zm-10.4-3.5a5.6 5.6 0 115.6-5.6 5.6 5.6 0 01-5.6 5.6z"></path></svg></button></form></div></div></div><div class="dz5d85-2 ijkWTi" role="navigation"><a class="jjui6k-0 bpKuNv sc-1ahzbiw-0 bpkyqV" href="/signup" role="button"><span class="jjui6k-1 BVTPe">註冊 / 登入</span></a><div class="fdq12b-0 dZxiDA"><a class="jjui6k-0 jpJQOT" role="button" title="更多"><span class="jjui6k-1 BVTPe"><svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24"><path d="M11.08 15.62l-4.69-4.69a1.31 1.31 0 01.92-2.24h9.38a1.31 1.31 0 01.92 2.24l-4.69 4.69a1.3 1.3 0 01-1.84 0z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></span></a></div></div></div></div><div class="bvk29r-0 jhIZYh"><div class="bvk29r-1 cXYfzh"><div class="sc-1bfxmuy-0 hkUAph"><a href="/forum/all"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24"><path d="M18.95 3H5.05A2.04 2.04 0 003 5.04v13.91A2.04 2.04 0 005.05 21h13.9A2.05 2.05 0 0021 18.96V5.03A2.05 2.05 0 0018.95 3zM6.68 17.73a1.64 1.64 0 111.64-1.64 1.64 1.64 0 01-1.64 1.64zm0-4.1A1.64 1.64 0 118.32 12a1.64 1.64 0 01-1.64 1.64zm0-4.08A1.64 1.64 0 118.32 7.9a1.64 1.64 0 01-1.64 1.64zm11.86 6.77a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.1a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.45a1 1 0 011-1h6.6a1 1 0 011 1zm0-4.08a1 1 0 01-1 1h-6.59a1 1 0 01-1-1v-.46a1 1 0 011-1h6.6a1 1 0 011 1z" data-name="icon_md_forum"></path></svg></div><div class="gthja3-1 fvZEcc">所有看板</div></div></a><a href="/forum/popular"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg aria-hidden="true" class="sc-husrwi dvqhOE" focusable="false" role="img" viewbox="0 0 24 24"><path d="M19.5 14.5a7.5 7.5 0 01-15 0 12.9 12.9 0 012.21-7.25l.02-.03a.18.18 0 01.04-.05.5.5 0 01.31-.15.51.51 0 01.55.46A3.36 3.36 0 0010.9 10a3.26 3.26 0 003.2-3.5 16.5 16.5 0 00-.32-2.9 1.63 1.63 0 01-.04-.19V3.4a.5.5 0 01.49-.5.51.51 0 01.28.08.45.45 0 01.1.09A15.95 15.95 0 0119.5 14.5zm-3.59-1.55a12.97 12.97 0 00-.22-1.32.5.5 0 00-.83-.27 7.93 7.93 0 01-3.73 1.77 2.94 2.94 0 00-2.63 2.93c0 2.55 3.3 4.32 5.95 1.5a5.75 5.75 0 001.46-4.6z" data-name="ic_hot"></path></svg></div><div class="gthja3-1 fvZEcc">即時熱門看板</div></div></a><a href="/goods"><div class="sc-11gkikh-0 jGtkKv"><div class="sc-1bfxmuy-1 iVjreC"><svg aria-hidden="true" class="sc-husrwi dvqhOE m2vgdk-0 jdZdIW" focusable="false" height="24" role="img" style="fill:#fff" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M20.962 9l-.994-5a2.156 2.156 0 00-1.987-2H6.019a2.156 2.156 0 00-1.987 2l-.994 5A2.34 2.34 0 004 11.269V20a2 2 0 002 2h12a2 2 0 002-2v-8.731A2.34 2.34 0 0020.962 9zM6.019 10a1 1 0 01-.993-1l.993-5H7v5.042a.993.993 0 01-.981.958zM9 9V4h2v5a1 1 0 01-2 0zm5.5 11h-5v-5.143a.937.937 0 011-.857h3a.937.937 0 011 .857zM15 9a1 1 0 01-2 0V4h2zm2.981 1A.993.993 0 0117 9.042V4h.981l.993 5a1 1 0 01-.993 1z"></path><path d="M0 0h24v24H0z" fill="none"></path></svg></div><div class="gthja3-1 fvZEcc">好物研究室</div></div></a><div class="sc-qz0f8b idVSLh"><div class="simp ...
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();</script><noscript><img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=gj89j1a8Dy000J" style="display:none" width="1"/></noscript></div><noscript><img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=33827916&amp;cv=2.0&amp;cj=1"/></noscript><script id="__INTL_REGISTRY__" type="application/json">{"meta.dcard_app.description_format":"廣受年輕人喜愛的 {product} 是台灣最大的匿名交流平台，舉凡時事話題、感情心情、吃喝玩樂、學習工作等，都有卡友陪你聊！","search.main.action":"搜尋","form_validation.is_required.message":"此欄位為必填。","signup.login_or_signup.action":"註冊 / 登入","settings.end_user_agreement.option":"服務條款","settings.faq.option":"常見問題","general.report_problem.description":"回報問題","general.brand_identification.description":"品牌識別","general.hiring.description":"徵才","general.business.description":"商業合作","general.free_to_download.description":"免費下載 App","settings.main.title":"設定","member.logout.action":"登出","general.more.action":"更多","forum_list.all_title.option":"所有看板","forum_list.realtime_popular.title":"即時熱門看板","ec.short.title":"好物研究室","forum_list.moderator.title":"板主相關","forum_list.favorites.title":"我的最愛","forum_list.selected.title_format":"{product} 精選看板","forum.all.title":"全部","collection.put.action":"收藏","post.anonymous.description":"匿名","time_format.less_than_seven_day.description_format":"{days} 天前","member.gender_male.option":"男","member.gender_female.option":"女","time_format.less_than_one_day.description_format":"{hours} 小時前","forum.welcome.message_format":"歡迎來到{forumName}板。"}</script><script id="__NEXT_DATA__" type="application/json">{"props":{"pageProps":{"layoutInitialProps":{"layoutInitialProps":{"layoutInitialProps":{},"componentInitialProps":{}},"componentInitialProps":{}},"componentInitialProps":{"envelope":{"pager":"legacy","options":{"paginationOptions":{"forumAlias":"all"},"isPessoalButNotLoggedin":false,"sourceKey":"hot"}},"forumAlias":"all","tabQuery":{},"tabs":[{"uiType":"button","alias":"hot","name":"熱門","listType":"legacy","nameMessage":{"type":"string","message":"熱門"},"isHome":false},{"uiType":"button","alias":"latest","name":"最新","listType":"legacy","nameMessage":{"type":"string","message":"最新"},"isHome":false},{"uiType":"button","alias":"subscribe","name":"追蹤","listType":"legacy","nameMessage":{"type":"string","message":"追蹤"},"isHome":false}],"query":{},"kbkPosts":[]}},"isLogin":false,"isMobile":false,"initialState":{"adItem":{"data":{"558bae61-cb3c-4604-b281-473b6bf1047d":[],"f0fc1371-7da6-472b-be89-6392f8869ea4":[],"2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[],"a0d23a73-66bb-4704-af18-286c6b0292f9":[],"63463c6f-e951-4d18-b559-6e6c5e629ec3":[],"e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[],"d1555d99-c344-499a-b0ee-fadfa2f2b216":[],"adUnitId=558bae61-cb3c-4604-b281-473b6bf1047d":[{"provider":"google","id":"/146730420/Desktop-Right-Top"}],"adUnitId=f0fc1371-7da6-472b-be89-6392f8869ea4":[{"provider":"google","id":"/146730420/Desktop-Beyond-FB"}],"adUnitId=2ff05f32-46b1-480c-9a6d-6ccbe55b7699":[{"provider":"google","id":"/146730420/Desktop-Right3"}],"adUnitId=a0d23a73-66bb-4704-af18-286c6b0292f9":[{"provider":"google","id":"/146730420/Desktop-Right4"}],"adUnitId=63463c6f-e951-4d18-b559-6e6c5e629ec3":[{"provider":"google","id":"/146730420/Desktop-RightBottom-Bottom"}],"adUnitId=e7b65598-5ac3-4c4e-83e5-255e6f68ad2a":[{"provider":"google","id":"/146730420/Desktop-Article-Bottom"}],"adUnitId=d1555d99-c344-499a-b0ee-fadfa2f2b216":[{"provider":"google","id":"/146730420/Desktop-Comments"}],"adUnitId=e4d31040-b6b8-4479-9585-a28bd1c16832":[{"provider":"google","id":"/146730420/Mobile-Web-Screen-Top"}],"adUnitId=0c24cee5-97e0-486b-9dc1-b7d36bea93cb":[{"provider":"google","id":"/146730420/Mobile-Web-Article-End"}],"adUnitId=49317a19-f96f-42df-9dee-76bf1d62b6f9":[{"provider":"google","id":"/146730420/Mweb-Pop ...

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
import requests
headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'}
r=requests.get('https://www.zhihu.com/explore',headers=headers)
print(r.text)
response=r.text
# Out:
# <!doctype html>
# <html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="知乎，中文互联网高质量的问答社区和创作者聚集的原创内容平台，于 2011 年 1 月正式上线，以「让人们更好地分享知识、经验和见解，找到自己的解答」为品牌使命。知乎凭借认真、专业、友善的社区氛围、独特的产品机制以及结构化和易获得的优质内容，聚集了中文互联网科技、商业、影视、时尚、文化等领域最具创造力的人群，已成为综合性、全品类、在诸多领域具有关键影响力的知识分享社区和创作者聚集的原创内容平台，建立起了以社区驱动的内容变现商业模式。"/><link data-react-helmet="true" rel="apple-touch-icon" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.a53ae37b.png"/><link data-react-helmet="true" rel="apple-touch-icon" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.a53ae37b.png" sizes="152x152"/><link data-react-helmet="true" rel="apple-touch-icon" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-120.bbce8f18.png" sizes="120x120"/><link data-react-helmet="true" rel="apple-touch-icon" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-76.cbade8f9.png" sizes="76x76"/><link data-react-helmet="true" rel="apple-touch-icon" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-60.8f6c52aa.png" sizes="60x60"/><link crossorigin="" rel="shortcut icon" type="image/x-icon" href="https://static.zhihu.com/heifetz/favicon.ico"/><link crossorigin="" rel="search" type="application/opensearchdescription+xml" href="https://static.zhihu.com/heifetz/search.xml" title="知乎"/><link rel="dns-prefetch" href="//static.zhimg.com"/><link rel="dns-prefetch" href="//pic1.zhimg.com"/><link rel="dns-prefetch" href="//pic2.zhimg.com"/><link rel="dns-prefetch" href="//pic3.zhimg.com"/><link rel="dns-prefetch" href="//pic4.zhimg.com"/><style>
# .u-safeAreaInset-top {
#   height: constant(safe-area-inset-top) !important;
#   height: env(safe-area-inset-top) !important;
#
# }
# .u-safeAreaInset-bottom {
#   height: constant(safe-area-inset-bottom) !important;
#   height: env(safe-area-inset-bottom) !important;
#
# }
# </style><link href="https://static.zhihu.com/heifetz/main.app.216a26f4.52f5e03efa5d6f29f658.css" crossorigin="" rel="stylesheet"/><link crossorigin="" href="https://static.zhihu.com/heifetz/main.explore-routes.216a26f4.bcfc6bb119fab6d535da.css" rel="stylesheet"/><script defer="" crossorigin="anonymous" src="https://unpkg.zhimg.com/@cfe/sentry-script@latest/dist/init.js" data-sentry-config="{&quot;dsn&quot;:&quot;https://2d8d764432cc4f6fb3bc78ab9528299d@crash2.zhihu.com/1224&quot;,&quot;sampleRate&quot;:0.1,&quot;release&quot;:&quot;2048-7f00bf76&quot;,&quot;ignoreErrorNames&quot;:[&quot;NetworkError&quot;,&quot;SecurityError&quot;],&quot;ignoreErrors&quot;:[&quot;origin message&quot;,&quot;Network request failed&quot;,&quot;无法 fetch&quot;,&quot;这个系统不支持该功能。&quot;,&quot;Can&#x27;t find variable: webkit&quot;,&quot;Can&#x27;t find variable: $&quot;,&quot;内存不足&quot;,&quot;out of memory&quot;,&quot;DOM Exception 18&quot;,&quot;The operation is insecure&quot;,&quot;[object Event]&quot;,&quot;[object FileError]&quot;,&quot;[object DOMError]&quot;,&quot;[object Object]&quot;,&quot;拒绝访问。&quot;,&quot;Maximum call stack size exceeded&quot;,&quot;缺少 JavaScript 对象&quot;,&quot;componentWillEnter&quot;,&quot;componentWillLeave&quot;,&quot;componentWillAppear&quot;,&quot;getInlineStyleAt&quot;,&quot;getCharacterList&quot;,&quot;draft-js&quot;,&quot;UploadError&quot;,{},{},{},&quot;Non-Error exception captured&quot;],&quot;whitelistUrls&quot;:[&quot;static.zhihu.com&quot;]}"></script></head><body><div id="root"><div><div class="LoadingBar"></div><div><header role="banner" class="Sticky AppHeader" data-za-module="TopNavBar"><style data-emotion-css="qqgmyv">.css-qqgmyv{width:auto;max-width:1156px;min-width:1000px;padding-left:16px;padding-right:30px;}.css-qqgmyv .AppHeader-userInfo{margin-left:30px;width:auto;}.css-qqgmyv .AppHeader-TabsLink.is-active,.css-qqgmyv .AppHeader-TabsLink:hover{color:#121212;}</style><div class="AppHeader-inner css-qqgmyv"><a href="//www.zhihu.com" aria-label="知乎"><svg viewBox="0 0 64 30" fill="#0066FF" width="64" height="30"><path d="M29.05 4.582H16.733V25.94h3.018l.403 2.572 4.081-2.572h4.815V4.582zm-5.207 18.69l-2.396 1.509-.235-1.508h-1.724V7.233h6.78v16.04h-2.425zM14.46 14.191H9.982c0-.471.033-.954.039-1.458v-5.5h5.106V5.935a1.352 1.352 0 0 0-.404-.957 1.378 1.378 0 0 0-.968-.396H5.783c.028-.088.056-.177.084-.255.274-.82 1.153-3.326 1.153-3.326a4.262 4.262 0 0 0-2.413.698c-.57.4-.912.682-1.371 1.946-.532 1.453-.997 2.856-1.31 3.693C1.444 8.674.28 11.025.28 11.025a5.85 5.85 0 0 0 2.52-.61c1.119-.593 1.679-1.502 2.054-2.883l.09-.3h2.334v5.5c0 .5-.045.982-.073 1.46h-4.12c-.71 0-1.39.278-1.893.775a2.638 2.638 0 0 0-.783 1.874h6.527a17.717 17.717 0 0 1-.778 3.649 16.796 16.796 0 0 1-3.012 5.273A33.104 33.104 0 0 1 0 28.74s3.13 1.175 5.425-.954c1.388-1.292 2.631-3.814 3.23-5.727a28.09 28.09 0 0 0 1.12-5.229h5.967v-1.37a1.254 1.254 0 0 0-.373-.899 1.279 1.279 0 0 0-.909-.37z"></path><path d="M11.27 19.675l-2.312 1.491 5.038 7.458a6.905 6.905 0 0 0 .672-2.218 3.15 3.15 0 0 0-.28-2.168l-3.118-4.563zM51.449 15.195V5.842c4.181-.205 7.988-.405 9.438-.483l.851-.05c.387-.399.885-2.395.689-3.021-.073-.25-.213-.666-.638-.555a33.279 33.279 0 0 1-4.277.727c-2.766.321-3.97.404-7.804.682-6.718.487-12.709.72-12.709.72a2.518 2.518 0 0 0 .788 1.834 2.567 2.567 0 0 0 1.883.706c2.278-.095 5.598-.25 8.996-.41v9.203h-12.78c0 .703.281 1.377.783 1.874a2.69 2.69 0 0 0 1.892.777h10.105v7.075c0 .887-.464 1.192-1.231 1.214h-3.92a4.15 4.15 0 0 0 .837 1.544 4.2 4.2 0 0 0 1.403 1.067 6.215 6.215 0 0 0 2.71.277c1.36-.066 2.967-.826 2.967-3.57v-7.607h11.28c.342 0 .67-.135.91-.374.242-.239.378-.563.378-.902v-1.375H51.449z"></path><path d="M42.614 8.873a2.304 2.304 0 0 0-1.508-.926 2.334 2.334 0 0 0-1.727.405l-.376.272 4.255 5.85 2.24-1.62-2.884-3.98zM57.35 8.68l-3.125 4.097 2.24 1.663 4.517-5.927-.375-.277a2.32 2.32 0 0 0-1.722-.452 2.327 2.327 0 0 0-1.536.896z"></path></svg></a><style data-emotion-css="g0ay3v">.css-g0ay3v{margin-left:25px;margin-righ ...

# %%
soup=BeautifulSoup(r.text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html data-hairline="true" data-theme="light" lang="zh"><head><meta charset="utf-8"/><title data-react-helmet="true">发现 - 知乎</title><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><meta content="webkit" name="renderer"/><meta content="webkit" name="force-rendering"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" name="google-site-verification"/><meta content="知乎，中文互联网高质量的问答社区和创作者聚集的原创内容平台，于 2011 年 1 月正式上线，以「让人们更好地分享知识、经验和见解，找到自己的解答」为品牌使命。知乎凭借认真、专业、友善的社区氛围、独特的产品机制以及结构化和易获得的优质内容，聚集了中文互联网科技、商业、影视、时尚、文化等领域最具创造力的人群，已成为综合性、全品类、在诸多领域具有关键影响力的知识分享社区和创作者聚集的原创内容平台，建立起了以社区驱动的内容变现商业模式。" name="description" property="og:description"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.a53ae37b.png" rel="apple-touch-icon"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-152.a53ae37b.png" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-120.bbce8f18.png" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-76.cbade8f9.png" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://static.zhihu.com/heifetz/assets/apple-touch-icon-60.8f6c52aa.png" rel="apple-touch-icon" sizes="60x60"/><link crossorigin="" href="https://static.zhihu.com/heifetz/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link crossorigin="" href="https://static.zhihu.com/heifetz/search.xml" rel="search" title="知乎" type="application/opensearchdescription+xml"/><link href="//static.zhimg.com" rel="dns-prefetch"/><link href="//pic1.zhimg.com" rel="dns-prefetch"/><link href="//pic2.zhimg.com" rel="dns-prefetch"/><link href="//pic3.zhimg.com" rel="dns-prefetch"/><link href="//pic4.zhimg.com" rel="dns-prefetch"/><style>
# .u-safeAreaInset-top {
#   height: constant(safe-area-inset-top) !important;
#   height: env(safe-area-inset-top) !important;
#
# }
# .u-safeAreaInset-bottom {
#   height: constant(safe-area-inset-bottom) !important;
#   height: env(safe-area-inset-bottom) !important;
#
# }
# </style><link crossorigin="" href="https://static.zhihu.com/heifetz/main.app.216a26f4.52f5e03efa5d6f29f658.css" rel="stylesheet"/><link crossorigin="" href="https://static.zhihu.com/heifetz/main.explore-routes.216a26f4.bcfc6bb119fab6d535da.css" rel="stylesheet"/><script crossorigin="anonymous" data-sentry-config="{&quot;dsn&quot;:&quot;https://2d8d764432cc4f6fb3bc78ab9528299d@crash2.zhihu.com/1224&quot;,&quot;sampleRate&quot;:0.1,&quot;release&quot;:&quot;2048-7f00bf76&quot;,&quot;ignoreErrorNames&quot;:[&quot;NetworkError&quot;,&quot;SecurityError&quot;],&quot;ignoreErrors&quot;:[&quot;origin message&quot;,&quot;Network request failed&quot;,&quot;无法 fetch&quot;,&quot;这个系统不支持该功能。&quot;,&quot;Can't find variable: webkit&quot;,&quot;Can't find variable: $&quot;,&quot;内存不足&quot;,&quot;out of memory&quot;,&quot;DOM Exception 18&quot;,&quot;The operation is insecure&quot;,&quot;[object Event]&quot;,&quot;[object FileError]&quot;,&quot;[object DOMError]&quot;,&quot;[object Object]&quot;,&quot;拒绝访问。&quot;,&quot;Maximum call stack size exceeded&quot;,&quot;缺少 JavaScript 对象&quot;,&quot;componentWillEnter&quot;,&quot;componentWillLeave&quot;,&quot;componentWillAppear&quot;,&quot;getInlineStyleAt&quot;,&quot;getCharacterList&quot;,&quot;draft-js&quot;,&quot;UploadError&quot;,{},{},{},&quot;Non-Error exception captured&quot;],&quot;whitelistUrls&quot;:[&quot;static.zhihu.com&quot;]}" defer="" src="https://unpkg.zhimg.com/@cfe/sentry-script@latest/dist/init.js"></script></head><body><div id="root"><div><div class="LoadingBar"></div><div><header class="Sticky AppHeader" data-za-module="TopNavBar" role="banner"><style data-emotion-css="qqgmyv">.css-qqgmyv{width:auto;max-width:1156px;min-width:1000px;padding-left:16px;padding-right:30px;}.css-qqgmyv .AppHeader-userInfo{margin-left:30px;width:auto;}.css-qqgmyv .AppHeader-TabsLink.is-active,.css-qqgmyv .AppHeader-TabsLink:hover{color:#121212;}</style><div class="AppHeader-inner css-qqgmyv"><a aria-label="知乎" href="//www.zhihu.com"><svg fill="#0066FF" height="30" viewbox="0 0 64 30" width="64"><path d="M29.05 4.582H16.733V25.94h3.018l.403 2.572 4.081-2.572h4.815V4.582zm-5.207 18.69l-2.396 1.509-.235-1.508h-1.724V7.233h6.78v16.04h-2.425zM14.46 14.191H9.982c0-.471.033-.954.039-1.458v-5.5h5.106V5.935a1.352 1.352 0 0 0-.404-.957 1.378 1.378 0 0 0-.968-.396H5.783c.028-.088.056-.177.084-.255.274-.82 1.153-3.326 1.153-3.326a4.262 4.262 0 0 0-2.413.698c-.57.4-.912.682-1.371 1.946-.532 1.453-.997 2.856-1.31 3.693C1.444 8.674.28 11.025.28 11.025a5.85 5.85 0 0 0 2.52-.61c1.119-.593 1.679-1.502 2.054-2.883l.09-.3h2.334v5.5c0 .5-.045.982-.073 1.46h-4.12c-.71 0-1.39.278-1.893.775a2.638 2.638 0 0 0-.783 1.874h6.527a17.717 17.717 0 0 1-.778 3.649 16.796 16.796 0 0 1-3.012 5.273A33.104 33.104 0 0 1 0 28.74s3.13 1.175 5.425-.954c1.388-1.292 2.631-3.814 3.23-5.727a28.09 28.09 0 0 0 1.12-5.229h5.967v-1.37a1.254 1.254 0 0 0-.373-.899 1.279 1.279 0 0 0-.909-.37z"></path><path d="M11.27 19.675l-2.312 1.491 5.038 7.458a6.905 6.905 0 0 0 .672-2.218 3.15 3.15 0 0 0-.28-2.168l-3.118-4.563zM51.449 15.195V5.842c4.181-.205 7.988-.405 9.438-.483l.851-.05c.387-.399.885-2.395.689-3.021-.073-.25-.213-.666-.638-.555a33.279 33.279 0 0 1-4.277.727c-2.766.321-3.97.404-7.804.682-6.718.487-12.709.72-12.709.72a2.518 2.518 0 0 0 .788 1.834 2.567 2.567 0 0 0 1.883.706c2.278-.095 5.598-.25 8.996-.41v9.203h-12.78c0 .703.281 1.377.783 1.874a2.69 2.69 0 0 0 1.892.777h10.105v7.075c0 .887-.464 1.192-1.231 1.214h-3.92a4.15 4.15 0 0 0 .837 1.544 4.2 4.2 0 0 0 1.403 1.067 6.215 6.215 0 0 0 2.71.277c1.36-.066 2.967-.826 2.967-3.57v-7.607h11.28c.342 0 .67-.135.91-.374.242-.239.378-.563.378-.902v-1.375H51.449z"></path><path d="M42.614 8.873a2.304 2.304 0 0 0-1.508-.926 2.334 2.334 0 0 0-1.727.405l-.376.272 4.255 5.85 2.24-1.62-2.884-3.98zM57.35 8.68l-3.125 4.097 2.24 1.663 4.517-5.927-.375-.277a2.32 2.32 0 0 0-1.722-.452 2.327 2.327 0 0 0-1.536.896z"></path></svg></a><style data-emotion-css="g0ay3v">.css-g0ay3v{margin-left:25px;margin-right:15px;}.c ...
